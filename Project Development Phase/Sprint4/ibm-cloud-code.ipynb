# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
# !pip install keras==2.2.4
# Out:
# ...
#   Using cached Keras-2.2.4-py2.py3-none-any.whl (312 kB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.7.2 requires keras<2.8,>=2.7.0, but you have keras 2.2.4 which is incompatible.
# ...

# %%
# !pip install tensorflow
# !pip install talos
# Out:
# ...
#      |████████████████████████████████| 56 kB 4.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 5.4 MB 31.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 26.4 MB 28.9 MB/s eta 0:00:01
# ...
#   Created wheel for chances: filename=chances-0.1.9-py3-none-any.whl size=41609 sha256=721710a42dd1df108e5be0a8788653de7ce78bfc550e0998c99a45ceb5d09283
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/c3/26/2b/8ae098b8e9dd7cc1fd0a9131c0f1efea60d710ff7906bf0ab4
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=ea2bde0a6d4020ea51934a62c27f77bf211a429baecd5ca562285d04e0858c5f
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built chances sklearn
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # **Image Data Augmentation**

# %%
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='dwGeBSQ91UhwyUSfbJbBVY4RV-XBixjfjdndafPN5qrH',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'ibmnaalaiyathiran-donotdelete-pr-ivs4sqtlzavqzi'
object_key = 'data.zip'

streaming_body_4 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
if not hasattr(streaming_body_4, "__iter__"): streaming_body_4.__iter__ = types.MethodType(__iter__, streaming_body_4)

# %%
from io import BytesIO
import zipfile
unzip = zipfile.ZipFile(BytesIO(streaming_body_4.read()), 'r')
file_paths = unzip.namelist()
for path in file_paths:
    unzip.extract(path)

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
ls
# Out:
# TEST_SET/  TRAIN_SET/

# %%
import os
files = os.listdir('/home/wsuser/work/TEST_SET')

# %% [markdown]
# # **Loading Data and performing Data Augmentation**

# %%
x_train=train_datagen.flow_from_directory(r'/home/wsuser/work/TEST_SET',target_size=(64,64),batch_size=32,class_mode='sparse')
x_test=train_datagen.flow_from_directory(r'/home/wsuser/work/TRAIN_SET',target_size=(64,64),batch_size=32,class_mode='sparse')
# Out:
# Found 929 images belonging to 5 classes.
# Found 4119 images belonging to 5 classes.

# %%
print(x_train.class_indices)
# Out:
# {'APPLES': 0, 'BANANA': 1, 'ORANGE': 2, 'PINEAPPLE': 3, 'WATERMELON': 4}

# %%
print(x_test.class_indices)
# Out:
# {'APPLES': 0, 'BANANA': 1, 'ORANGE': 2, 'PINEAPPLE': 3, 'WATERMELON': 4}

# %%
from collections import Counter as c
c(x_train .labels)
# Out:
# Counter({0: 266, 1: 415, 2: 248})

# %% [markdown]
# # Importing necessasry library

# %%
import numpy as np#used for numerical analysis
import tensorflow #open source used for both ML and DL for computation
from tensorflow.keras.models import Sequential #it is a plain stack of layers
from tensorflow.keras import layers #A layer consists of a tensor-in tensor-out computation function
#Dense layer is the regular deeply connected neural network layer
from tensorflow.keras.layers import Dense,Flatten
#Faltten-used fot flattening the input or change the dimension
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout #Convolutional layer
#MaxPooling2D-for downsampling the image
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Initializing The Model

# %%
model = Sequential()

# %% [markdown]
# # Creating the model

# %%
# Initializing the CNN
classifier = Sequential()

# First convolution layer and pooling
classifier.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Second convolution layer and pooling
classifier.add(Conv2D(32, (3, 3), activation='relu'))

# input_shape is going to be the pooled feature maps from the previous convolution layer
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Flattening the layers
classifier.add(Flatten())

# Adding a fully connected layer
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dense(units=5, activation='softmax')) # softmax for more than 2

classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 5)                 645
#
# ...
# Total params: 813,733
# Trainable params: 813,733
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compiling the model

# %%
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Fitting the model

# %%
classifier.fit_generator(
        generator=x_train,steps_per_epoch = len(x_train),
        epochs=10, validation_data=x_test,validation_steps = len(x_test))
# Out:
# /tmp/wsuser/ipykernel_164/3242859618.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   classifier.fit_generator(
# Epoch 1/10
# 30/30 [==============================] - 29s 960ms/step - loss: 0.9334 - accuracy: 0.5684 - val_loss: 1.8279 - val_accuracy: 0.5608
# Epoch 2/10
# 30/30 [==============================] - 28s 959ms/step - loss: 0.6772 - accuracy: 0.7191 - val_loss: 1.4748 - val_accuracy: 0.5693
# Epoch 3/10
# 30/30 [==============================] - 27s 933ms/step - loss: 0.6697 - accuracy: 0.7147 - val_loss: 1.6531 - val_accuracy: 0.6295
# Epoch 4/10
# 30/30 [==============================] - 28s 960ms/step - loss: 0.6125 - accuracy: 0.7449 - val_loss: 1.6064 - val_accuracy: 0.6485
# Epoch 5/10
# 30/30 [==============================] - 28s 951ms/step - loss: 0.5164 - accuracy: 0.8019 - val_loss: 1.7294 - val_accuracy: 0.6344
# Epoch 6/10
# ...

# %% [markdown]
# # Saving the model

# %%
classifier.save('nutrition.h5')

# %%
# !tar -zcvf image-classification-model_new.tgz nutrition.h5
# Out:
# nutrition.h5

# %%
ls -1
# Out:
# image-classification-model_new.tgz
# nutrition.h5
# TEST_SET/
# TRAIN_SET/

# %%
# !pip install watson-machine-learning-client --upgrade
# Out:
# ...
#      |████████████████████████████████| 538 kB 10.2 MB/s eta 0:00:01
# ...

# %%
from ibm_watson_machine_learning import APIClient
wml_credentials = {
    "url" : "https://us-south.ml.cloud.ibm.com",
    "apikey":"xIbdYJWATFaqkg5Lj7VFiHwyZHZEYZnK0c6yf1wWLk9"
}
client = APIClient(wml_credentials)

# %%
client = APIClient(wml_credentials)

# %%
def guid_from_space_name(client, space_name):
    space = client.spaces.get_details()
    return(next(item for item in space['resources'] if item['entity']["name"] == space_name)['metadata']['id'])

# %%
space_uid = guid_from_space_name(client, 'ibm-naalaiya-thiran')
print(space_uid)
# Out:
# 2d51de66-1ee0-49e4-8307-8b3585028713

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list()
# Out:
# -----------------------------  ------------------------------------  ----
# NAME                           ASSET_ID                              TYPE
# default_py3.6                  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# kernel-spark3.2-scala2.12      020d69ce-7ac1-5e68-ac1a-31189867356a  base
# pytorch-onnx_1.3-py3.7-edt     069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6        09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12     09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# pytorch-onnx_rt22.1-py3.9      0b848dd4-e681-5599-be41-b5f6fccc6471  base
# ai-function_0.1-py3.6          0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                     0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod   1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6              10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# tensorflow_1.15-py3.6-ddl      111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# ...

# %%
software_spec_uid = client.software_specifications.get_uid_by_name("tensorflow_rt22.1-py3.9")
software_spec_uid
# Out:
# 'acd9c798-6974-5d2f-a657-ce06e986df4d'

# %%
model_details = client.repository.store_model(model = 'image-classification-model_new.tgz', meta_props = {
    client.repository.ModelMetaNames.NAME:"CNN",
    client.repository.ModelMetaNames.TYPE:"tensorflow_2.7",
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID:software_spec_uid
})
model_id = client.repository.get_model_uid(model_details)
# Out:
# This method is deprecated, please use get_model_id()
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/ibm_watson_machine_learning/repository.py:1453: UserWarning: This method is deprecated, please use get_model_id()
#   warn("This method is deprecated, please use get_model_id()")

# %%
model_id
client.repository.download(model_id, 'image-classification-model_new.tgz')
# Out:
# 'c5db7591-e6b1-4da6-bfbf-e39fa7f19ef6'

# %% [markdown]
#  # Testing the Model

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model=load_model('nutrition.h5')

# %%
img = image.load_img("/home/wsuser/work/TEST_SET/APPLES/n07740461_9461.jpg",target_size= (64,64))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
pred = classifier.predict(x)
pred
# Out:
# array([[1., 0., 0., 0., 0.]], dtype=float32)

# %%
index=['APPLES', 'BANANA', 'ORANGE','PINEAPPLE','WATERMELON']
index[np.argmax(pred)]
# Out:
# 'APPLES'
